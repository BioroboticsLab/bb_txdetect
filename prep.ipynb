# %%
# %run init_steps.py
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# 100%|██████████| 2007/2007 [00:00<00:00, 2298.53it/s]
# 14125it [00:00, 370093.35it/s]
# Ground truth events loaded: 2007
# Unique frame ids: 14125
# ...
# 100%|██████████| 2007/2007 [00:00<00:00, 2374.92it/s]
# done

# %%
display(len(verified_events),len(verified_events)/2007)
# Out:
# 145
# 0.07224713502740408

# %%
from get_images import get_center_frame_image, rotate_image, get_center_frame_index, crop_image
import matplotlib.pyplot as plt
for i in range(10):
    event = verified_events[i]
    img = get_center_frame_image(event)
    f,axes = plt.subplots(1,2, sharex=True, sharey=True)
    axes[0].imshow(img)
    axes[1].imshow(rotate_image(img,event,get_center_frame_index(event)))
    plt.tight_layout()
    plt.show()

    f,axes = plt.subplots(1,1, sharex=True, sharey=True)
    c = crop_image(rotate_image(img,event,get_center_frame_index(event)))
    plt.imshow(c)

    plt.show()

# %%
import numpy as np
for i in tqdm(range(10)):
    event = verified_events[i]
    rotated = crop_image(rotate_image(get_center_frame_image(event),
                                      event,
                                      get_center_frame_index(event)))
    np.save("output/images/{}.npy".format(i),rotated)
    plt.imsave(fname="output/images/{}.png".format(i), arr=rotated)
    
print("done")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-7-ab5453a97af7> in <module>()
#       5                                       event,
#       6                                       get_center_frame_index(event)))
# ----> 7     np.save("images/{}.npy".format(i),rotated)
#       8     plt.imsave(fname="images/{}.png".format(i), arr=rotated)
#       9
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     488         if not file.endswith('.npy'):
#     489             file = file + '.npy'
# --> 490         fid = open(file, "wb")
#     491         own_fid = True
#     492     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/0.npy'

# %%
for i in range(10):
    plt.imshow(np.load("output/images/{}.npy".format(i)))
    plt.show()

# %%
# %run rotate.py
event = verified_events[0]
images = get_all_images(event)
# Out:
# 100%|██████████| 43/43 [04:28<00:00,  6.25s/it]

# %%
import numpy as np
for i in tqdm(range(len(images))):
    rotated = crop_image(rotate_image(images[i], event, i))
    np.save("output/event00/{0:03d}.npy".format(i), rotated)
    plt.imsave(fname="output/event00/{0:03d}.png".format(i), arr=rotated)
# Out:
# 100%|██████████| 43/43 [00:01<00:00, 32.69it/s]
# done
